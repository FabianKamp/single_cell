# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
folder = r'C:\Users\Kamp\Documents\hbp\segments'
file = 'm18_081000_p1_PC_FiringPattern_metadata_segments.csv'
filepath = os.path.join(folder, file)

# %%
data = pd.read_csv(filepath, index_col=0)
for k in data: 
    fig, ax = plt.subplots()
    ax.plot(data[k])
data.head()
# Out:
#       53.86     103.57     204.02      304.1    403.72     503.09
# 0 -72.58606 -72.937010 -73.043820 -72.555540 -71.65527 -72.204590
# 1 -72.58606 -72.875980 -72.967530 -72.540280 -71.73157 -72.235110
# 2 -72.66235 -72.875980 -72.967530 -72.540280 -71.70105 -72.265625
# 3 -72.55554 -72.860720 -73.028564 -72.525024 -71.68579 -72.296140
# 4 -72.60132 -72.891235 -73.013306 -72.509766 -71.73157 -72.326660
